# %% [markdown]
# # Шаг 3: Декомпиляция APK и генерация набора данных

# %%
import json
import requests
from requests_toolbelt.multipart.encoder import MultipartEncoder
import subprocess
import os
import json
import csv
import pandas as pd
import time
import numpy as np
import shutil
import glob

# %%
APK_BASE_PATH = "D:\\ETU\\VKR\\scanned_apps\\"
SMALI_PATH = "D:\\ETU\\VKR\\decompile\\"
APKTOOL_PATH = "C:\\Windows\\" #apktool.bat path
JSON_PATH = "D:\\ETU\\VKR\\json\\"
CSV_PATH = "D:\\ETU\\VKR\\"

headers=["code", "CWE_ID", "description", "vulnerability_status"]

# %%
def default_data_row(row):
    code = str(row).strip()
    cwe_id = ""
    desc = ""
    vulnerability_status = 0
    csv_data_row = [code, cwe_id, desc, vulnerability_status]
    return csv_data_row

# %%
def delete_irrelevant_rows(file):
    df = []
    starts = (".", ":", "#", "goto", "value", "\"", "}", "return", "throw", "accessFlags", "name")
    for entry in file:
        if not entry[0].strip().startswith(starts):
            df.append(entry)
    return df

# %%
def delete_rows_with_no_code(df):        
    filtered = df["code"] != ""
    df = df[filtered]
    df.reset_index()
    return df

# %%
def get_csv_source(apk_source_path, path):
    file_path = apk_source_path + path + ".smali"
    source = pd.read_csv(file_path, encoding='utf-8', header=None, delimiter="\0",skip_blank_lines=False).fillna("")
    return source

# %%
def decompile_with_apktool(apk):
    command = APKTOOL_PATH + "apktool.bat d " + APK_BASE_PATH + apk + " -o " + SMALI_PATH + apk
    os.system(command)

# %% [markdown]
# ## Генерация набора данных

# %%
apk_list = os.listdir(APK_BASE_PATH)
vulnerability_dataset = []

for apk in apk_list:
    print("Generating vulnerability dataset from: " + apk)
    
    try:
        with open(JSON_PATH + apk + ".json") as json_data:
            d = json.load(json_data)
            cwe_list = d["cwe"]
            json_data.close()
    except Exception as ej:
        print("!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!")
        print(str(ej))
        continue
        
    if not cwe_list: continue
    
    decompile_with_apktool(apk)

    file_list = []
    apk_source_path = SMALI_PATH + apk

    for path, subdirs, files in os.walk(apk_source_path, topdown=False):
        for name in files:
            file_list.append(os.path.join(path, name))

    for entry in cwe_list:
        try:
            file_path = [s for s in file_list if entry["path"] + ".smali" in s]
            if file_path: file_path = file_path[0]
            else: break
            source = pd.read_csv(file_path, encoding='utf-8', header=None, delimiter="\0",skip_blank_lines=False).fillna("")

            file_df = [] 
            for index, row in source.iterrows():
                file_df.append(default_data_row(row[0]))

            file_df = pd.DataFrame(file_df, columns = headers)
            file_df = delete_rows_with_no_code(file_df)

            for cwe_data in entry["list"]:
                is_caller = False
                for index, row in file_df.iterrows():
                    if all(x in str(row["code"]) for x in [".method", cwe_data["caller"]]):
                        is_caller = True
                        continue
                    if is_caller:
                        if all(x in str(row["code"]) for x in ["invoke", cwe_data["target"]]):
                            file_df.at[index, "CWE_ID"] = cwe_data["id"]
                            file_df.at[index, "description"] = cwe_data["description"]
                            file_df.at[index, "vulnerability_status"] = 1
                            break
        except Exception as ei:
            print("!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!")
            print(str(ei))
            continue

        file_tolist = file_df.values.tolist()
        vulnerability_dataset.extend(delete_irrelevant_rows(file_tolist))
        file_list = [value for value in file_list if value != file_path]

    if os.path.isdir(SMALI_PATH + apk):
        shutil.rmtree(SMALI_PATH + apk)

vulberability_dataframe = pd.DataFrame(vulnerability_dataset, columns = headers)

vulberability_dataframe.to_csv('vulnerability_dataset_BALANCE.csv', sep=',', encoding='utf-8', index=False)
# Out:
# Generating vulnerability dataset from: acca.apk
# Generating vulnerability dataset from: acdisplay.apk
# Generating vulnerability dataset from: activityforcenewtask.apk
# Generating vulnerability dataset from: activity-launcher.apk
# Generating vulnerability dataset from: activity-launcher-fork.apk
# Generating vulnerability dataset from: adaptive-brightness-tile.apk
# Generating vulnerability dataset from: adbio.apk
# Generating vulnerability dataset from: adblock-plus.apk
# Generating vulnerability dataset from: adfree.apk
# Generating vulnerability dataset from: adguard-content-blocker.apk
# Generating vulnerability dataset from: admincontrol.apk
# Generating vulnerability dataset from: adsilence.apk
# Generating vulnerability dataset from: afh-downloader.apk
# Generating vulnerability dataset from: afwall+.apk
# Generating vulnerability dataset from: ag-store.apk
# Generating vulnerability dataset from: aicia.apk
# Generating vulnerability dataset from: aiproute.apk
# Generating vulnerability dataset from: airmessage.apk
# Generating vulnerability dataset from: airunlock.apk
# Generating vulnerability dataset from: aix-weather-widget.apk
# Generating vulnerability dataset from: akvo-rsr-up.apk
# Generating vulnerability dataset from: alexandria.apk
# Generating vulnerability dataset from: alldebrid.apk
# Generating vulnerability dataset from: allsafe.apk
# Generating vulnerability dataset from: alovoa.apk
# Generating vulnerability dataset from: alovoa-2.apk
# Generating vulnerability dataset from: alt-launcher.apk
# Generating vulnerability dataset from: alwayson.apk
# Generating vulnerability dataset from: always-on-amoled.apk
# Generating vulnerability dataset from: always-on-amoled-plugin.apk
# Generating vulnerability dataset from: always-on-display-toggle.apk
# Generating vulnerability dataset from: amaze-file-manager.apk
# Generating vulnerability dataset from: amaze-file-utilities.apk
# Generating vulnerability dataset from: ambient-weather-dashclock-extension.apk
# Generating vulnerability dataset from: amethyst.apk
# Generating vulnerability dataset from: andfhem.apk
# Generating vulnerability dataset from: andhrystone.apk
# Generating vulnerability dataset from: androdns.apk
# Generating vulnerability dataset from: AndroGoat.apk
# Generating vulnerability dataset from: android-cache-cleaner.apk
# Generating vulnerability dataset from: androidcpg.apk
# Generating vulnerability dataset from: android-explorer.apk
# Generating vulnerability dataset from: android-permissions.apk
# Generating vulnerability dataset from: androidpn-client.apk
# Generating vulnerability dataset from: android-token.apk
# Generating vulnerability dataset from: android-version.apk
# Generating vulnerability dataset from: andstatus.apk
# Generating vulnerability dataset from: andsys-~-apps.apk
# Generating vulnerability dataset from: anemo.apk
# Generating vulnerability dataset from: anihyou-anilist-client.apk
# Generating vulnerability dataset from: aniki.apk
# Generating vulnerability dataset from: animepipe.apk
# Generating vulnerability dataset from: anode.apk
# Generating vulnerability dataset from: anonaddy.apk
# Generating vulnerability dataset from: 4pda.apk
# Generating vulnerability dataset from: 8vim-2.apk
# Generating vulnerability dataset from: acaldav.apk
# Generating vulnerability dataset from: anothermonitor.apk
# Generating vulnerability dataset from: another-rss.apk
# Generating vulnerability dataset from: anxray.apk
# Generating vulnerability dataset from: aodify.apk
# Generating vulnerability dataset from: aokpco.apk
# Generating vulnerability dataset from: apg.apk
# Generating vulnerability dataset from: apk-explorer-editor.apk
# Generating vulnerability dataset from: apk-extractor.apk
# Generating vulnerability dataset from: apkmirror.apk
# Generating vulnerability dataset from: apkshare.apk
# Generating vulnerability dataset from: apktrack.apk
# Generating vulnerability dataset from: apn-settings.apk
# Generating vulnerability dataset from: appbak.apk
# Generating vulnerability dataset from: applications-info.apk
# Generating vulnerability dataset from: applist.apk
# Generating vulnerability dataset from: app-list.apk
# Generating vulnerability dataset from: app-manager.apk
# Generating vulnerability dataset from: apps2org.apk
# Generating vulnerability dataset from: appspackages-info.apk
# Generating vulnerability dataset from: archlinux-forums.apk
# Generating vulnerability dataset from: archon-packager.apk
# Generating vulnerability dataset from: archwiki-viewer.apk
# Generating vulnerability dataset from: aria2android.apk
# Generating vulnerability dataset from: aria2app.apk
# Generating vulnerability dataset from: arso-vreme.apk
# Generating vulnerability dataset from: ashell.apk
# Generating vulnerability dataset from: aster-launcher.apk
# Generating vulnerability dataset from: atalk.apk
# Generating vulnerability dataset from: atomic.apk
# Generating vulnerability dataset from: atop.apk
# Generating vulnerability dataset from: atox.apk
# Generating vulnerability dataset from: audile.apk
# Generating vulnerability dataset from: aurora-store-2.apk
# Generating vulnerability dataset from: ausweisapp2.apk
# Generating vulnerability dataset from: auto-autorotate.apk
# Generating vulnerability dataset from: autodark.apk
# Generating vulnerability dataset from: autodnd.apk
# Generating vulnerability dataset from: automation.apk
# Generating vulnerability dataset from: autonotify.apk
# Generating vulnerability dataset from: autostarts.apk
# Generating vulnerability dataset from: backgroundrestrictor.apk
# Generating vulnerability dataset from: backup-privacy-friendly.apk
# Generating vulnerability dataset from: bad-pixel-detector.apk
# Generating vulnerability dataset from: balance.apk
# Generating vulnerability dataset from: baldphone.apk
# Generating vulnerability dataset from: bandcampdirect.apk
# Generating vulnerability dataset from: bangumi.apk
# Generating vulnerability dataset from: baresip.apk
# Generating vulnerability dataset from: baresip+.apk
# Generating vulnerability dataset from: baria.apk
# Generating vulnerability dataset from: based-cooking.apk
# Generating vulnerability dataset from: basketbuild-downloader.apk
# Generating vulnerability dataset from: batch-uninstaller.apk
# Generating vulnerability dataset from: batterybot.apk
# Generating vulnerability dataset from: batterybot-pro.apk
# Generating vulnerability dataset from: batterycalibrate.apk
# Generating vulnerability dataset from: batterycalibration.apk
# Generating vulnerability dataset from: battery-charge-limit.apk
# Generating vulnerability dataset from: batteryfu.apk
# Generating vulnerability dataset from: battery-notification.apk
# Generating vulnerability dataset from: battery-tool.apk
# Generating vulnerability dataset from: beacon-locator.apk
# Generating vulnerability dataset from: behat-reporter.apk
# Generating vulnerability dataset from: behe-explorer.apk
# Generating vulnerability dataset from: bepo-clavier-externe.apk
# Generating vulnerability dataset from: beta-updater-for-whatsapp.apk
# Generating vulnerability dataset from: betterbatterystats.apk
# Generating vulnerability dataset from: better-schedule.apk
# Generating vulnerability dataset from: betteruntis.apk
# Generating vulnerability dataset from: bhagavad-gita.apk
# Generating vulnerability dataset from: bienvenido-a-internet.apk
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# [Errno 2] No such file or directory: 'D:\\ETU\\VKR\\json\\bienvenido-a-internet.apk.json'
# Generating vulnerability dataset from: biglybt-torrent-downloader.apk
# Generating vulnerability dataset from: biliyou.apk
# Generating vulnerability dataset from: birthday-calendar.apk
# Generating vulnerability dataset from: bk-doorlock.apk
# Generating vulnerability dataset from: blippex.apk
# Generating vulnerability dataset from: blitzmail.apk
# Generating vulnerability dataset from: blocker.apk
# Generating vulnerability dataset from: bombusmod.apk
# Generating vulnerability dataset from: bonjourbrowser.apk
# Generating vulnerability dataset from: booklist.apk
# Generating vulnerability dataset from: bookmarkos.apk
# Generating vulnerability dataset from: box-box.apk
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# [Errno 2] No such file or directory: 'D:\\ETU\\VKR\\json\\box-box.apk.json'
# Generating vulnerability dataset from: breezy-weather.apk
# Generating vulnerability dataset from: brightness-widget.apk
# Generating vulnerability dataset from: browser.apk
# Generating vulnerability dataset from: browser-intercept-share-url.apk
# Generating vulnerability dataset from: btc-map.apk
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# [Errno 2] No such file or directory: 'D:\\ETU\\VKR\\json\\btc-map.apk.json'
# Generating vulnerability dataset from: dankchat.apk
# Generating vulnerability dataset from: danxi.apk
# Generating vulnerability dataset from: dashchan.apk
# Generating vulnerability dataset from: databackup.apk
# Generating vulnerability dataset from: databag.apk
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# [Errno 2] No such file or directory: 'D:\\ETU\\VKR\\json\\databag.apk.json'
# Generating vulnerability dataset from: data-monitor.apk
# Generating vulnerability dataset from: datastats.apk
# Generating vulnerability dataset from: davdroid.apk
# Generating vulnerability dataset from: dawdle.apk
# Generating vulnerability dataset from: dawn.apk
# Generating vulnerability dataset from: dbcleaner-for-whatsapp.apk
# Generating vulnerability dataset from: debdroid.apk
# Generating vulnerability dataset from: debloater.apk
# Generating vulnerability dataset from: deck.apk
# Generating vulnerability dataset from: decsync-cc.apk
# Generating vulnerability dataset from: deedum.apk
# Generating vulnerability dataset from: defo-ech-apps.apk
# Generating vulnerability dataset from: delta-chat.apk
# Generating vulnerability dataset from: demo-musix.apk
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# [Errno 2] No such file or directory: 'D:\\ETU\\VKR\\json\\demo-musix.apk.json'
# Generating vulnerability dataset from: buckwheat-budget-manager.apk
# Generating vulnerability dataset from: bulkshare-2.apk
# Generating vulnerability dataset from: bunny-media-editor.apk
# Generating vulnerability dataset from: buran.apk
# Generating vulnerability dataset from: busybox.apk
# Generating vulnerability dataset from: busybox-installer.apk
# Generating vulnerability dataset from: bvd.apk
# Generating vulnerability dataset from: cache-cleaner.apk
# Generating vulnerability dataset from: cadroid.apk
# Generating vulnerability dataset from: caffeine-tile.apk
# Generating vulnerability dataset from: calculator++.apk
# Generating vulnerability dataset from: calef-calendar-entry-formatter.apk
# Generating vulnerability dataset from: calendar-ics-adapter.apk
# Generating vulnerability dataset from: calendar-notifications-plus.apk
# Generating vulnerability dataset from: calendar-trigger.apk
# Generating vulnerability dataset from: call-recorder.apk
# Generating vulnerability dataset from: camcov.apk
# Generating vulnerability dataset from: canada-weather-radar.apk
# Generating vulnerability dataset from: candle.apk
# Generating vulnerability dataset from: candle-2.apk
# Generating vulnerability dataset from: canta.apk
# Generating vulnerability dataset from: capod-companion-for-airpods.apk
# Generating vulnerability dataset from: captive-portal-controller.apk
# Generating vulnerability dataset from: catapult.apk
# Generating vulnerability dataset from: cbapp-client-for-using-commonbooking-websites.apk
# Generating vulnerability dataset from: ceno-browser.apk
# Generating vulnerability dataset from: chairlock.apk
# Generating vulnerability dataset from: change-detection.apk
# Generating vulnerability dataset from: check-network.apk
# Generating vulnerability dataset from: checkup.apk
# Generating vulnerability dataset from: cheogram.apk
# Generating vulnerability dataset from: cherry.apk
# Generating vulnerability dataset from: chiki-chiki-tube.apk
# Generating vulnerability dataset from: chinesettstflite.apk
# Generating vulnerability dataset from: chiver.apk
# Generating vulnerability dataset from: circles.apk
# Generating vulnerability dataset from: ckpool-watcher.apk
# Generating vulnerability dataset from: clashmetaforandroid.apk
# Generating vulnerability dataset from: clearclipboard.apk
# Generating vulnerability dataset from: clima.apk
# Generating vulnerability dataset from: clipboard-beam.apk
# Generating vulnerability dataset from: clipboardcleaner.apk
# Generating vulnerability dataset from: clipeus.apk
# Generating vulnerability dataset from: clipious.apk
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# [Errno 2] No such file or directory: 'D:\\ETU\\VKR\\json\\clipious.apk.json'
# Generating vulnerability dataset from: clip-stack.apk
# Generating vulnerability dataset from: clock.apk
# Generating vulnerability dataset from: clock-widget-2.apk
# Generating vulnerability dataset from: clock-you.apk
# Generating vulnerability dataset from: clover.apk
# Generating vulnerability dataset from: cmus-remote.apk
# Generating vulnerability dataset from: coffee.apk
# Generating vulnerability dataset from: colorblendr-root.apk
# Generating vulnerability dataset from: color-namer.apk
# Generating vulnerability dataset from: colorpicker.apk
# Generating vulnerability dataset from: colorsniffer.apk
# Generating vulnerability dataset from: commons.apk
# Generating vulnerability dataset from: commonslab.apk
# Generating vulnerability dataset from: commonslab-2.apk
# Generating vulnerability dataset from: connectbot.apk
# Generating vulnerability dataset from: connect-you.apk
# Generating vulnerability dataset from: conscrypt-provider.apk
# Generating vulnerability dataset from: contact-merger.apk
# Generating vulnerability dataset from: conversations.apk
# Generating vulnerability dataset from: copy-sms-code-otp-helper.apk
# Generating vulnerability dataset from: corona-stats.apk
# Generating vulnerability dataset from: cpu-info.apk
# Generating vulnerability dataset from: cpu-stats.apk
# Generating vulnerability dataset from: critical-maps.apk
# Generating vulnerability dataset from: croc.apk
# Generating vulnerability dataset from: crond.apk
# Generating vulnerability dataset from: cryptomator.apk
# Generating vulnerability dataset from: cryptot.apk
# Generating vulnerability dataset from: custom-search.apk
# Generating vulnerability dataset from: custom-uploader.apk
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# [Errno 2] No such file or directory: 'D:\\ETU\\VKR\\json\\custom-uploader.apk.json'
# Generating vulnerability dataset from: cyanogenmod-installer.apk
# Generating vulnerability dataset from: daedalus.apk
# Generating vulnerability dataset from: dailyal.apk
# Generating vulnerability dataset from: dandelior.apk
# Generating vulnerability dataset from: feeder.apk
# Generating vulnerability dataset from: deskcon.apk
# Generating vulnerability dataset from: destiny.apk
# Generating vulnerability dataset from: dgapps.apk
# Generating vulnerability dataset from: dialer.apk
# Generating vulnerability dataset from: diaspora-2.apk
# Generating vulnerability dataset from: dib2qm.apk
# Generating vulnerability dataset from: dicio-assistant.apk
# Generating vulnerability dataset from: dimmer.apk
# Generating vulnerability dataset from: dinomail.apk
# Generating vulnerability dataset from: diode.apk
# Generating vulnerability dataset from: diolinux.apk
# Generating vulnerability dataset from: dir.apk
# Generating vulnerability dataset from: disable-battery-warnings.apk
# Generating vulnerability dataset from: disable-manager.apk
# Generating vulnerability dataset from: discord-timestamp-inserter.apk
# Generating vulnerability dataset from: discreet-launcher.apk
# Generating vulnerability dataset from: discuz-hub.apk
# Generating vulnerability dataset from: disroot-app.apk
# Generating vulnerability dataset from: dns66.apk
# Generating vulnerability dataset from: dnsfilter.apk
# Generating vulnerability dataset from: dns-hero.apk
# Generating vulnerability dataset from: dokuwiki.apk
# Generating vulnerability dataset from: dolidroid.apk
# Generating vulnerability dataset from: domodroid.apk
# Generating vulnerability dataset from: dontkillmyapp.apk
# Generating vulnerability dataset from: do-swimmer.apk
# Generating vulnerability dataset from: downloadfilesweb.apk
# Generating vulnerability dataset from: download-navi.apk
# Generating vulnerability dataset from: dpi-tunnel.apk
# Generating vulnerability dataset from: dpi-tunnel-v2.apk
# Generating vulnerability dataset from: droidbeard.apk
# Generating vulnerability dataset from: droidentify.apk
# Generating vulnerability dataset from: droid-examiner.apk
# Generating vulnerability dataset from: droidify.apk
# Generating vulnerability dataset from: droidshows.apk
# Generating vulnerability dataset from: droidtr-keyboard.apk
# Generating vulnerability dataset from: droidwall.apk
# Generating vulnerability dataset from: drowser.apk
# Generating vulnerability dataset from: dsbdirect.apk
# Generating vulnerability dataset from: dsu-sideloader.apk
# Generating vulnerability dataset from: duckduckgo.apk
# Generating vulnerability dataset from: duorem.apk
# Generating vulnerability dataset from: dvd.apk
# Generating vulnerability dataset from: easer.apk
# Generating vulnerability dataset from: easer-beta.apk
# Generating vulnerability dataset from: easylight.apk
# Generating vulnerability dataset from: easy-open-link.apk
# Generating vulnerability dataset from: easyphone.apk
# Generating vulnerability dataset from: easyrss.apk
# Generating vulnerability dataset from: easysshfs.apk
# Generating vulnerability dataset from: easy-weather.apk
# Generating vulnerability dataset from: ebooks.apk
# Generating vulnerability dataset from: editor.apk
# Generating vulnerability dataset from: eduroamcat.apk
# Generating vulnerability dataset from: eduvpn.apk
# Generating vulnerability dataset from: einkbro.apk
# Generating vulnerability dataset from: element-riotim.apk
# Generating vulnerability dataset from: elfeed-mobile.apk
# Generating vulnerability dataset from: elloshare.apk
# Generating vulnerability dataset from: email.apk
# Generating vulnerability dataset from: emerald-launcher.apk
# Generating vulnerability dataset from: energize.apk
# Generating vulnerability dataset from: entrust-identityguard-unblocker.apk
# Generating vulnerability dataset from: equran.apk
# Generating vulnerability dataset from: er-riki%C3%B0-opi%C3%B0.apk
# Generating vulnerability dataset from: etchdroid.apk
# Generating vulnerability dataset from: eternity.apk
# Generating vulnerability dataset from: etesync.apk
# Generating vulnerability dataset from: etesync-notes.apk
# Generating vulnerability dataset from: etherwake.apk
# Generating vulnerability dataset from: evergreen-wishlist.apk
# Generating vulnerability dataset from: export-contacts.apk
# Generating vulnerability dataset from: extirpater.apk
# Generating vulnerability dataset from: eyesfree-shell.apk
# Generating vulnerability dataset from: facebook-lite.apk
# Generating vulnerability dataset from: facebook-notifications.apk
# Generating vulnerability dataset from: fairemail.apk
# Generating vulnerability dataset from: fakestandby.apk
# Generating vulnerability dataset from: fast-brightness-control-widget.apk
# Generating vulnerability dataset from: fast-draw.apk
# Generating vulnerability dataset from: faster-app-search-tool.apk
# Generating vulnerability dataset from: fbclient.apk
# Generating vulnerability dataset from: fcitx5-for-android.apk
# Generating vulnerability dataset from: fcitx5-for-android-anthy-plugin.apk
# Generating vulnerability dataset from: fcitx5-for-android-chewing-plugin.apk
# Generating vulnerability dataset from: fcitx5-for-android-clipboard-filter-plugin.apk
# Generating vulnerability dataset from: fcitx5-for-android-hangul-plugin.apk
# Generating vulnerability dataset from: fcitx5-for-android-jyutping-plugin.apk
# Generating vulnerability dataset from: fcitx5-for-android-rime-plugin.apk
# Generating vulnerability dataset from: fcitx5-for-android-sayura-plugin.apk
# Generating vulnerability dataset from: fcitx5-for-android-unikey-plugin.apk
# Generating vulnerability dataset from: fdroid-basic-alpha.apk
# Generating vulnerability dataset from: fdroid-classic.apk
# Generating vulnerability dataset from: fdroid-kaltura-device-info.apk
# Generating vulnerability dataset from: fdroid-nearby.apk
# Generating vulnerability dataset from: fdroid-privileged-extension.apk
# Generating vulnerability dataset from: fedi-photo.apk
# Generating vulnerability dataset from: fediphotolineage.apk
